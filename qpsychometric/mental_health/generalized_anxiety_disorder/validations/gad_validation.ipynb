# %%
from qpsychometric.questionnaire_validator import QuestionnaireValidator
from qpsychometric.mental_health.generalized_anxiety_disorder import gad_questionnaire

# %%
# Import gad questions
gad_qmnli_df = gad_questionnaire['QMNLI']
gad_questions = gad_qmnli_df.get_questions()

gad_factors = list(set([q()._descriptor['Factor'] for q in gad_questions]))

# %%
# Create validator instance
validator = QuestionnaireValidator(
    questionnaire_name="gad",
    questions=gad_questions,
    factors=gad_factors,
    result_path="results/",
    update=True,
)

# %%
results = validator.run_validation()
# Out:
# ...
# Running Complete Validation for gad Questionnaire
# ...
#
# Running model evaluation with 16 question variants...
# Evaluating models:   0%|          | 0/20 [00:00<?, ?it/s]
# Evaluating model: typeform/distilbert-base-uncased-mnli
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# ...

# %%
results.keys()
# Out:
# dict_keys(['results_csv', 'content_validity', 'cronbach_alpha', 'correlations'])

# %%
results['results_csv']
# Out:
# PosixPath('results/gad_mnli_results.csv')

# %%
import pandas as pd
df = pd.read_csv("/home/amonfadi/thesis/qpsychometric/qpsychometric/mental_health/generalized_anxiety_disorder/validations/results/gad_mnli_results.csv")
len(set(df["model"]))
# Out:
# 20

# %%
set(df["model"])
# Out:
# {'FacebookAI/roberta-large-mnli',
#  'MoritzLaurer/DeBERTa-v3-large-mnli-fever-anli-ling-wanli',
#  'MoritzLaurer/mDeBERTa-v3-base-mnli-xnli',
#  'Narsil/deberta-large-mnli-zero-cls',
#  'cross-encoder/nli-MiniLM2-L6-H768',
#  'cross-encoder/nli-deberta-base',
#  'digitalepidemiologylab/covid-twitter-bert-v2-mnli',
#  'facebook/bart-large-mnli',
#  'joeddav/bart-large-mnli-yahoo-answers',
#  'joeddav/xlm-roberta-large-xnli',
#  'katanemo/bart-large-mnli',
#  'mjwong/e5-large-mnli',
#  'mjwong/multilingual-e5-large-xnli',
#  'navteca/bart-large-mnli',
#  'navteca/nli-deberta-v3-large',
#  'symanto/mpnet-base-snli-mnli',
#  'typeform/distilbert-base-uncased-mnli',
#  'typeform/mobilebert-uncased-mnli',
#  'utahnlp/mnli_microsoft_deberta-v3-large_seed-3',
#  'valhalla/distilbart-mnli-12-6'}

# %%
results['content_validity']
# Out:
#            semantic_similarity  cola_score  silhouette_score
# Q
# GAD7GAD71             0.557745    0.946092          0.142015
# GAD7GAD74             0.747575    0.977711          0.398470
# GAD7GAD75             0.657422    0.973803          0.526373
# GAD7GAD73             0.723309    0.963669          0.540147
# GAD7GAD72             0.546181    0.972943          0.553140
# GAD7GAD77             0.500933    0.963594          0.648059
# GAD7GAD76             0.661457    0.970781          0.660592

# %%
semantic_results = validator.get_semantic_similarity()
cola_results = validator.get_cola_score()
# Out:
# ...
# Calculating COLA scores: 100%|██████████| 2/2 [00:00<00:00,  2.73it/s]

# %%
cola_results
# Out:
#            cola_score
# GAD7GAD71    0.946092
# GAD7GAD73    0.963669

# %%
semantic_results
# Out:
#            semantic_similarity
# GAD7GAD71             0.557745
# GAD7GAD73             0.723309

# %%
results['cronbach_alpha']["overall"]
# Out:
# (0.8836500235035342, array([0.785, 0.947]))

# %%
results['cronbach_alpha']["factors"]
# Out:
# {'GAD7': (0.8836500235035342, array([0.785, 0.947]))}

# %%
data_df = results['cronbach_alpha']['data_df']
validator.test_question_affect_on_cronbach_alpha(data_df)
# Out:
# GAD7 Alpha: (0.8836500235035342, array([0.785, 0.947]))
# without: GAD7GAD71 Alpha: (0.8762549685063213, array([0.768, 0.944]))
# without: GAD7GAD72 Alpha: (0.8624636253953761, array([0.742, 0.938]))
# without: GAD7GAD73 Alpha: (0.8719205794541939, array([0.76 , 0.942]))
# without: GAD7GAD74 Alpha: (0.8954760040437375, array([0.804, 0.953]))
# without: GAD7GAD75 Alpha: (0.8552598104172662, array([0.729, 0.935]))
# without: GAD7GAD76 Alpha: (0.8389823309871602, array([0.698, 0.928]))
# without: GAD7GAD77 Alpha: (0.8662560684445176, array([0.749, 0.94 ]))

# %% [markdown]
# GAD7 Alpha: (0.912452760330734, array([0.838, 0.96 ]))
# without: GAD7GAD71 Alpha: (0.8797941919684087, array([0.775, 0.946]))
# without: GAD7GAD72 Alpha: (0.8998895847210767, array([0.812, 0.955]))
# without: GAD7GAD73 Alpha: (0.9055013981189922, array([0.823, 0.957]))
# without: GAD7GAD74 Alpha: (0.9313485472488474, array([0.871, 0.969]))
# without: GAD7GAD75 Alpha: (0.8927382427289815, array([0.799, 0.952]))
# without: GAD7GAD76 Alpha: (0.8831181476188675, array([0.781, 0.947]))
# without: GAD7GAD77 Alpha: (0.9034015934809196, array([0.819, 0.957]))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
results['correlations']
# Out:
#      GAD7  gad
# GAD7    -  ***
# gad   1.0    -
