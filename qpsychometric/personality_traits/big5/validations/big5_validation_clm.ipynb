# %%
import os
os.chdir('/home/shistikk/qpsychometric')
print(os.getcwd())
# Out:
# /home/shistikk/qpsychometric

# %%
from qpsychometric.questionnaire_clm_validator import QuestionnaireCLMValidator
from qpsychometric.personality_traits.big5 import big5_questionnaire
# Out:
# /home/shistikk/.conda/envs/astrin/lib/python3.12/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# 2026-07-12 14:52:52.600982: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-07-12 14:52:52.622014: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-07-12 14:52:52.628497: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-07-12 14:52:52.644670: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-12 14:52:54.147830: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Import big5 questions
big5_qmnli_df = big5_questionnaire['QCLM']
big5_questions = big5_qmnli_df.get_questions()

big5_factors = list(set([q()._descriptor['Factor'] for q in big5_questions]))

# %%
# Create validator instance
validator = QuestionnaireCLMValidator(
    questionnaire_name="big5",
    questions=big5_questions,
    factors=big5_factors,
    result_path="results/",
    update=True
)
# Out:
# Loading validation models...
# /home/shistikk/.conda/envs/astrin/lib/python3.12/site-packages/transformers/convert_slow_tokenizer.py:559: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Device set to use cuda:0
# Models loaded successfully.
# Splitting 14 questions...
# Generated 112 question variants.
# Initialized big5 CLM Validator:
#   - Questions: 14
#   - Factors: ['Extraversion', 'Conscientiousness', 'Openness', 'Neuroticism', 'Agreeableness']
#   - Scales: ['answer']
#   - Index: ['question']
#   - Device: 0
#   - Instruct (chat) models: 10
#   - Result path: results

# %%
results = validator.run_validation()
# Out:
# ======================================================================
# Running Complete CLM Validation for big5 Questionnaire
# ======================================================================
#
# Running model evaluation with 112 question variants...
# Evaluating models:   0%|          | 0/16 [00:00<?, ?it/s]
# Evaluating model: google/gemma-2-2b  (mode=raw, type=base)
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# Processing questions:   0%|          | 0/112 [00:00<?, ?it/s]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
#
# Evaluating model: google/gemma-2-9b  (mode=raw, type=base)
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Device set to use cuda:0
# Error evaluating google/gemma-2-9b: CUDA out of memory. Tried to allocate 196.00 MiB. GPU 0 has a total capacity of 23.52 GiB of which 189.75 MiB is free. Including non-PyTorch memory, this process has 23.32 GiB memory in use. Of the allocated memory 22.85 GiB is allocated by PyTorch, and 20.68 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# Evaluating model: google/gemma-3-270m  (mode=raw, type=base)
# Device set to use cuda:0
# Processing questions:   0%|          | 0/112 [00:00<?, ?it/s]
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
#
# Evaluating model: meta-llama/Llama-3.2-1B  (mode=raw, type=base)
# Device set to use cuda:0
# Processing questions:   0%|          | 0/112 [00:00<?, ?it/s]
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
#
# Evaluating model: meta-llama/Llama-3.2-3B  (mode=raw, type=base)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# Processing questions:   0%|          | 0/112 [00:00<?, ?it/s]
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
#
# Evaluating model: microsoft/MediPhi  (mode=raw, type=base)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# Processing questions:   0%|          | 0/112 [00:00<?, ?it/s]
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
#
# Evaluating model: microsoft/MediPhi-PubMed  (mode=raw, type=base)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# Processing questions:   0%|          | 0/112 [00:00<?, ?it/s]
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# Evaluating model: Qwen/Qwen2.5-3B  (mode=raw, type=base)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# Processing questions:   0%|          | 0/112 [00:00<?, ?it/s]
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
#
# Evaluating model: google/gemma-3-1b-it  (mode=chat, type=chat)
# Device set to use cuda:0
# Processing questions:   0%|          | 0/112 [00:00<?, ?it/s]
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# ...
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
#
# Evaluating model: Qwen/Qwen3-1.7B  (mode=chat, type=chat)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# Processing questions:   0%|          | 0/112 [00:00<?, ?it/s]
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
#
# Evaluating model: Qwen/Qwen3-4B  (mode=chat, type=chat)
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# Processing questions:   0%|          | 0/112 [00:00<?, ?it/s]
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# 'intensifier'
# silhouette_score is set to -1
# agg function failed [how->mean,dtype->object]
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
# Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
# silhouette_score is set to -1
#
# ✓ Model evaluation complete. Results saved to: results/big5_clm_results.csv
#
# ======================================================================
# Calculating Content Validity Metrics (all models)
# ======================================================================
#
# ✓ Content validity metrics saved to: results/linguistic_acceptability.csv
#
# Content Validity Results:
#                         semantic_similarity  cola_score  silhouette_score
# Q
# BIG5Extraversion8                  0.435042    0.937527          0.167322
# BIG5Conscientiousness6             0.629863    0.955648          0.168169
# BIG5Extraversion9                  0.498504    0.938092          0.197838
# BIG5Openness2                      0.379201    0.935918          0.205361
# BIG5Agreeableness10                0.587231    0.942350          0.250130
# BIG5Extraversion7                  0.531386    0.945699          0.279581
# BIG5Conscientiousness4             0.490294    0.939677          0.305983
# BIG5Neuroticism14                  0.431773    0.896290          0.351709
# BIG5Openness1                      0.684637    0.789448          0.355120
# BIG5Agreeableness12                0.634475    0.912659          0.363378
# BIG5Neuroticism13                  0.503359    0.949541          0.366525
# BIG5Agreeableness11                0.574616    0.940456          0.419683
# BIG5Openness3                      0.562031    0.934153          0.470201
# BIG5Conscientiousness5             0.393983    0.937400               NaN
#
# ======================================================================
# Calculating Internal Consistency (Cronbach's Alpha, all models)
# ======================================================================
#
# Cronbach Alpha:
# Extraversion: (0.6382202713562126, array([0.141, 0.868]))
# Conscientiousness: (0.893099214314837, array([0.746, 0.961]))
# Openness: (0.9106492628484165, array([0.788, 0.967]))
# Neuroticism: (0.9786573728935373, array([0.936, 0.993]))
# Agreeableness: (0.9598511994954881, array([0.905, 0.985]))
#
# big5 Overall: (0.8815304273477484, array([0.77 , 0.953]))
#
# ======================================================================
# Calculating Factor Correlations (all models)
# ======================================================================
#
# ✓ Factor correlations (spearman):
#                   Extraversion Conscientiousness Openness Neuroticism  \
# Extraversion                 -                 *       **
# Conscientiousness        0.529                 -       **           *
# Openness                 0.671             0.693        -
# Neuroticism             -0.246            -0.521   -0.021           -
# Agreeableness            0.764             0.689    0.925      -0.089
# big5                     0.775             0.718    0.961      -0.064
#
#                   Agreeableness big5
# Extraversion                ***  ***
# Conscientiousness            **   **
# Openness                    ***  ***
# Neuroticism
# Agreeableness                 -  ***
# big5                      0.964    -
#
# ======================================================================
# Validation Complete!
# ======================================================================
# Results saved in: results

# %%
results.keys()
# Out:
# dict_keys(['results_csv', 'content_validity', 'cronbach_alpha', 'correlations'])

# %%
results_csv = results['results_csv']

# %%
from pathlib import Path

p = Path('results/big5_clm_results.csv')

# %%
import pandas as pd
df = pd.read_csv(p)
len(set(df["model"]))
# Out:
# 15

# %%
set(df["model"])
# Out:
# {'Qwen/Qwen2.5-3B',
#  'Qwen/Qwen3-1.7B',
#  'Qwen/Qwen3-4B',
#  'google/gemma-2-2b',
#  'google/gemma-3-1b-it',
#  'google/gemma-3-270m',
#  'google/gemma-3-270m-it',
#  'meta-llama/Llama-3.2-1B',
#  'meta-llama/Llama-3.2-1B-Instruct',
#  'meta-llama/Llama-3.2-3B',
#  'meta-llama/Llama-3.2-3B-Instruct',
#  'microsoft/MediPhi',
#  'microsoft/MediPhi-Instruct',
#  'microsoft/MediPhi-PubMed',
#  'microsoft/Phi-4-mini-instruct'}

# %% [markdown]
# ## Analysis - base models

# %%
content_validity_base = validator.calc_content_validity(results_csv, model_type='base')
content_validity_base
# Out:
# ✓ Content validity metrics (base) saved to: results/linguistic_acceptability_base.csv
#                         semantic_similarity  cola_score  silhouette_score
# Q
# BIG5Extraversion9                  0.498504    0.938092          0.201398
# BIG5Extraversion8                  0.435042    0.937527          0.205781
# BIG5Openness2                      0.379201    0.935918          0.230514
# BIG5Agreeableness10                0.587231    0.942350          0.250157
# BIG5Conscientiousness4             0.490294    0.939677          0.306282
# BIG5Extraversion7                  0.531386    0.945699          0.311226
# BIG5Agreeableness12                0.634475    0.912659          0.324054
# BIG5Openness1                      0.684637    0.789448          0.325567
# BIG5Conscientiousness6             0.629863    0.955648          0.331727
# BIG5Agreeableness11                0.574616    0.940456          0.406317
# BIG5Neuroticism13                  0.503359    0.949541          0.426744
# BIG5Openness3                      0.562031    0.934153          0.431562
# BIG5Neuroticism14                  0.431773    0.896290          0.511442
# BIG5Conscientiousness5             0.393983    0.937400               NaN

# %%
alpha_base = validator.calc_cronbach_alpha(results_csv, model_type='base')
print('overall:', alpha_base['overall'])
print('factors:', alpha_base['factors'])
# Out:
# Cronbach Alpha (base):
# Extraversion: (0.6272191255352877, array([-0.39 ,  0.931]))
# Conscientiousness: (0.8920228338977971, array([0.597, 0.98 ]))
# Openness: (0.9132227208580314, array([0.676, 0.984]))
# Neuroticism: (0.984070849060193, array([0.907, 0.997]))
# Agreeableness: (0.9827940473507091, array([0.936, 0.997]))
#
# big5 Overall (base): (0.8969456333797179, array([0.735, 0.979]))
# overall: (0.8969456333797179, array([0.735, 0.979]))
# factors: {'Extraversion': (0.6272191255352877, array([-0.39 ,  0.931])), 'Conscientiousness': (0.8920228338977971, array([0.597, 0.98 ])), 'Openness': (0.9132227208580314, array([0.676, 0.984])), 'Neuroticism': (0.984070849060193, array([0.907, 0.997])), 'Agreeableness': (0.9827940473507091, array([0.936, 0.997]))}

# %%
validator.test_question_affect_on_cronbach_alpha(alpha_base['data_df'])
# Out:
# All Questions Alpha: (0.8969456333797179, array([0.735, 0.979]))
# without: BIG5Agreeableness10 Alpha: (0.8735015745330508, array([0.672, 0.974]))
# without: BIG5Agreeableness11 Alpha: (0.8779662577215265, array([0.684, 0.975]))
# without: BIG5Agreeableness12 Alpha: (0.8753297159114451, array([0.677, 0.975]))
# without: BIG5Conscientiousness4 Alpha: (0.8753022045794054, array([0.677, 0.975]))
# without: BIG5Conscientiousness5 Alpha: (0.8846645908010261, array([0.701, 0.977]))
# without: BIG5Conscientiousness6 Alpha: (0.8940756497286302, array([0.726, 0.979]))
# without: BIG5Extraversion7 Alpha: (0.8978864986610511, array([0.736, 0.979]))
# without: BIG5Extraversion8 Alpha: (0.8920151012787826, array([0.72 , 0.978]))
# without: BIG5Extraversion9 Alpha: (0.8813074744166614, array([0.693, 0.976]))
# without: BIG5Neuroticism13 Alpha: (0.926484138371197, array([0.81 , 0.985]))
# without: BIG5Neuroticism14 Alpha: (0.9238109612646682, array([0.803, 0.985]))
# without: BIG5Openness1 Alpha: (0.8690949263215306, array([0.661, 0.974]))
# without: BIG5Openness2 Alpha: (0.8874239658385754, array([0.708, 0.977]))
# without: BIG5Openness3 Alpha: (0.8683397999941593, array([0.659, 0.973]))

# %%
correlations_base = validator.calc_correlations(results_csv, model_type='base')
correlations_base
# Out:
# ✓ Factor correlations (base) (spearman):
#                   Extraversion Conscientiousness Openness Neuroticism  \
# Extraversion                 -                          *
# Conscientiousness         0.75                 -
# Openness                 0.857             0.679        -
# Neuroticism             -0.143            -0.536      0.0           -
# Agreeableness              1.0              0.75    0.857      -0.143
# big5                     0.893              0.75    0.964      -0.036
#
#                   Agreeableness big5
# Extraversion                ***   **
# Conscientiousness
# Openness                      *  ***
# Neuroticism
# Agreeableness                 -   **
# big5                      0.893    -
#                   Extraversion Conscientiousness Openness Neuroticism  \
# Extraversion                 -                          *
# Conscientiousness         0.75                 -
# Openness                 0.857             0.679        -
# Neuroticism             -0.143            -0.536      0.0           -
# Agreeableness              1.0              0.75    0.857      -0.143
# big5                     0.893              0.75    0.964      -0.036
#
#                   Agreeableness big5
# Extraversion                ***   **
# Conscientiousness
# Openness                      *  ***
# Neuroticism
# Agreeableness                 -   **
# big5                      0.893    -

# %% [markdown]
# ## Analysis - instruct models

# %%
content_validity_chat = validator.calc_content_validity(results_csv, model_type='chat')
content_validity_chat
# Out:
# ✓ Content validity metrics (chat) saved to: results/linguistic_acceptability_chat.csv
#                         semantic_similarity  cola_score  silhouette_score
# Q
# BIG5Conscientiousness6             0.629863    0.955648          0.025056
# BIG5Extraversion8                  0.435042    0.937527          0.133671
# BIG5Openness2                      0.379201    0.935918          0.183351
# BIG5Extraversion9                  0.498504    0.938092          0.194724
# BIG5Neuroticism14                  0.431773    0.896290          0.211943
# BIG5Agreeableness10                0.587231    0.942350          0.250107
# BIG5Extraversion7                  0.531386    0.945699          0.251893
# BIG5Conscientiousness4             0.490294    0.939677          0.305722
# BIG5Neuroticism13                  0.503359    0.949541          0.313833
# BIG5Openness1                      0.684637    0.789448          0.380979
# BIG5Agreeableness12                0.634475    0.912659          0.397787
# BIG5Agreeableness11                0.574616    0.940456          0.431379
# BIG5Openness3                      0.562031    0.934153          0.504010
# BIG5Conscientiousness5             0.393983    0.937400               NaN

# %%
alpha_chat = validator.calc_cronbach_alpha(results_csv, model_type='chat')
print('overall:', alpha_chat['overall'])
print('factors:', alpha_chat['factors'])
# Out:
# Cronbach Alpha (chat):
# Extraversion: (0.7854953243087606, array([0.275, 0.953]))
# Conscientiousness: (0.8421034991710498, array([0.466, 0.966]))
# Openness: (0.939976360950697, array([0.797, 0.987]))
# Neuroticism: (0.5738622190506368, array([-1.129,  0.915]))
# Agreeableness: (0.9132985623348021, array([0.707, 0.981]))
#
# big5 Overall (chat): (0.9235425253351074, array([0.814, 0.982]))
# overall: (0.9235425253351074, array([0.814, 0.982]))
# factors: {'Extraversion': (0.7854953243087606, array([0.275, 0.953])), 'Conscientiousness': (0.8421034991710498, array([0.466, 0.966])), 'Openness': (0.939976360950697, array([0.797, 0.987])), 'Neuroticism': (0.5738622190506368, array([-1.129,  0.915])), 'Agreeableness': (0.9132985623348021, array([0.707, 0.981]))}

# %%
validator.test_question_affect_on_cronbach_alpha(alpha_chat['data_df'])
# Out:
# All Questions Alpha: (0.9235425253351074, array([0.814, 0.982]))
# without: BIG5Agreeableness10 Alpha: (0.9058024943776487, array([0.77 , 0.978]))
# without: BIG5Agreeableness11 Alpha: (0.9170601559200684, array([0.797, 0.98 ]))
# without: BIG5Agreeableness12 Alpha: (0.9067713907574092, array([0.772, 0.978]))
# without: BIG5Conscientiousness4 Alpha: (0.9140888805683043, array([0.79, 0.98]))
# without: BIG5Conscientiousness5 Alpha: (0.9105493767187844, array([0.782, 0.979]))
# without: BIG5Conscientiousness6 Alpha: (0.9215097837304443, array([0.808, 0.981]))
# without: BIG5Extraversion7 Alpha: (0.9268758105300052, array([0.821, 0.983]))
# without: BIG5Extraversion8 Alpha: (0.9228129864901324, array([0.811, 0.982]))
# without: BIG5Extraversion9 Alpha: (0.9117970152498296, array([0.785, 0.979]))
# without: BIG5Neuroticism13 Alpha: (0.9347846456828901, array([0.841, 0.985]))
# without: BIG5Neuroticism14 Alpha: (0.9372355486631228, array([0.847, 0.985]))
# without: BIG5Openness1 Alpha: (0.9057726249274439, array([0.77 , 0.978]))
# without: BIG5Openness2 Alpha: (0.9075367015936202, array([0.774, 0.978]))
# without: BIG5Openness3 Alpha: (0.9182265853961862, array([0.8  , 0.981]))

# %%
correlations_chat = validator.calc_correlations(results_csv, model_type='chat')
correlations_chat
# Out:
# ✓ Factor correlations (chat) (spearman):
#                   Extraversion Conscientiousness Openness Neuroticism  \
# Extraversion                 -
# Conscientiousness        0.619                 -        *
# Openness                 0.548             0.738        -
# Neuroticism             -0.524            -0.571   -0.262           -
# Agreeableness            0.643             0.762    0.833      -0.167
# big5                     0.762              0.81    0.857      -0.333
#
#                   Agreeableness big5
# Extraversion                       *
# Conscientiousness             *    *
# Openness                      *   **
# Neuroticism
# Agreeableness                 -  ***
# big5                      0.976    -
#                   Extraversion Conscientiousness Openness Neuroticism  \
# Extraversion                 -
# Conscientiousness        0.619                 -        *
# Openness                 0.548             0.738        -
# Neuroticism             -0.524            -0.571   -0.262           -
# Agreeableness            0.643             0.762    0.833      -0.167
# big5                     0.762              0.81    0.857      -0.333
#
#                   Agreeableness big5
# Extraversion                       *
# Conscientiousness             *    *
# Openness                      *   **
# Neuroticism
# Agreeableness                 -  ***
# big5                      0.976    -

# %% [markdown]
# ## Item-level linguistic metrics (model-independent)

# %%
semantic_results = validator.get_semantic_similarity()
cola_results = validator.get_cola_score()
# Out:
# Calculating semantic similarity:   0%|          | 0/14 [00:00<?, ?it/s]
# Calculating COLA scores:   0%|          | 0/14 [00:00<?, ?it/s]

# %%
cola_results
# Out:
#                         cola_score
# BIG5Openness1             0.789448
# BIG5Openness2             0.935918
# BIG5Openness3             0.934153
# BIG5Conscientiousness4    0.939677
# BIG5Conscientiousness5    0.937400
# BIG5Conscientiousness6    0.955648
# BIG5Extraversion7         0.945699
# BIG5Extraversion8         0.937527
# BIG5Extraversion9         0.938092
# BIG5Agreeableness10       0.942350
# BIG5Agreeableness11       0.940456
# BIG5Agreeableness12       0.912659
# BIG5Neuroticism13         0.949541
# BIG5Neuroticism14         0.896290

# %%
semantic_results
# Out:
#                         semantic_similarity
# BIG5Openness1                      0.684637
# BIG5Openness2                      0.379201
# BIG5Openness3                      0.562031
# BIG5Conscientiousness4             0.490294
# BIG5Conscientiousness5             0.393983
# BIG5Conscientiousness6             0.629863
# BIG5Extraversion7                  0.531386
# BIG5Extraversion8                  0.435042
# BIG5Extraversion9                  0.498504
# BIG5Agreeableness10                0.587231
# BIG5Agreeableness11                0.574616
# BIG5Agreeableness12                0.634475
# BIG5Neuroticism13                  0.503359
# BIG5Neuroticism14                  0.431773
